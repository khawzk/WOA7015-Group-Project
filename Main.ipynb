# %%
import os
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv(r"C:\Users\user\Downloads\test02.csv")

# %%
#Get ECG and Resp data for respective 80 waves,most work will be done on here.
ecgdata = data.head(80)
# Out:
#            RATE       FETURE1       FETURE2       FETURE3       FETURE4  \
# 0   126.0504202  -0.978338115  -0.976829476  -0.976096495  -0.972632775
# 1   123.9669421  -0.617229851  -0.639035331  -0.592662992  -0.637238948
# 2   132.1585903  -0.838670764  -0.884708228  -0.818168116  -0.821156441
# 3   116.7315175  -0.980956379  -0.977145876  -0.982336195  -0.978423296
# 4   117.6470588  -0.676937232  -0.668069853  -0.682207068  -0.674341994
# ..          ...           ...           ...           ...           ...
# 75  131.5789474  -0.488946415   -0.45819861  -0.469513893  -0.461344511
# 76  124.2236025  -0.614143381  -0.346549919  -0.445715533  -0.385011413
# 77  134.2281879   0.211154819   0.723536931   0.528778843   0.646502861
# 78  182.5557809  -1.213271544  -1.219836663  -1.215443196  -1.214968687
# 79  182.5557809  -1.160479856  -1.122230437  -1.134784267  -1.123839383
#
#          FETURE5       FETURE6       FETURE7       FETURE8       FETURE9  ...  \
# ...

# %%
#Get time data for respective 80 waves
timedata = data.tail(81)
timedata. columns = timedata. iloc[0]
timedata = timedata.tail(80) 
timedata
# Out:
# 80          RATE TIME1   TIME2  TIME3   TIME4 TIME5   TIME6  TIME7   TIME8  \
# 81   126.0504202     0  1.0025  2.005  3.0075  4.01  5.0125  6.015  7.0175
# 82   123.9669421     0  0.8275  1.655  2.4825  3.31  4.1375  4.965  5.7925
# 83   132.1585903     0  0.5975  1.195  1.7925  2.39  2.9875  3.585  4.1825
# 84   116.7315175     0    0.69   1.38    2.07  2.76    3.45   4.14    4.83
# 85   117.6470588     0   0.685   1.37   2.055  2.74   3.425   4.11   4.795
# ..           ...   ...     ...    ...     ...   ...     ...    ...     ...
# 156  131.5789474     0    1.15    2.3    3.45   4.6    5.75    6.9    8.05
# 157  124.2236025     0   1.385   2.77   4.155  5.54   6.925   8.31   9.695
# 158  134.2281879     0  1.3075  2.615  3.9225  5.23  6.5375  7.845  9.1525
# 159  182.5557809     0  1.2925  2.585  3.8775  5.17  6.4625  7.755  9.0475
# 160  182.5557809     0  1.3125  2.625  3.9375  5.25  6.5625  7.875  9.1875
#
# ...

# %%
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers.core import Dense, Activation, Dropout
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.utils import shuffle
