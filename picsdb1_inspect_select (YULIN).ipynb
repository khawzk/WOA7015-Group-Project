# %% [markdown]
# # Preterm Infant Cardio-Respiratory Signals Database

# %% [markdown]
# Source: https://physionet.org/content/picsdb/1.0.0/

# %% [markdown]
# ## Python prelude

# %% [markdown]
# Import basic packages

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import wfdb # read Physionet/picsdb file format
from picsdb import *
from wfdb import processing
from numba import jit

# %% [markdown]
# ## PART 1: Initial Inspection

# %% [markdown]
# ### Data import

# %% [markdown]
# **Assumption**: data directory is in the current folder and has not been renamed after download from Physionet.
#  (Adapt if necessary)

# %%
#base_dir = os.getcwd()
#data_dir = os.path.join(base_dir, "preterm-infant-cardio-respiratory-signals-database-1.0.0")
#print("base directory: ", base_dir)
#print("data directory: ", data_dir)
data_dir="/Users/lyl69/Desktop/Sets/"

# %% [markdown]
# Make a list of all files in this directory, used later to iterate over all files.

# %%
L = os.listdir(data_dir)
for l in L:
    print(l)
# Out:
# ANNOTATORS
# infant10_ecg.atr
# infant10_ecg.dat
# infant10_ecg.hea
# infant10_ecg.qrsc
# infant10_resp.dat
# infant10_resp.hea
# infant10_resp.resp
# infant1_ecg.atr
# infant1_ecg.dat
# infant1_ecg.hea
# infant1_ecg.qrsc
# infant1_resp.dat
# infant1_resp.hea
# infant1_resp.resp
# infant2_ecg.atr
# infant2_ecg.dat
# infant2_ecg.hea
# infant2_ecg.qrsc
# infant2_resp.dat
# infant2_resp.hea
# infant2_resp.resp
# infant3_ecg.atr
# infant3_ecg.dat
# infant3_ecg.hea
# infant3_ecg.qrsc
# infant3_resp.dat
# infant3_resp.hea
# infant3_resp.resp
# infant4_ecg.atr
# infant4_ecg.dat
# infant4_ecg.hea
# infant4_ecg.qrsc
# infant4_resp.dat
# infant4_resp.hea
# infant4_resp.resp
# infant5_ecg.atr
# infant5_ecg.dat
# infant5_ecg.hea
# infant5_ecg.qrsc
# infant5_resp.dat
# infant5_resp.hea
# infant5_resp.resp
# infant6_ecg.atr
# infant6_ecg.dat
# infant6_ecg.hea
# infant6_ecg.qrsc
# infant6_resp.dat
# infant6_resp.hea
# infant6_resp.resp
# infant7_ecg.atr
# infant7_ecg.dat
# infant7_ecg.hea
# infant7_ecg.qrsc
# infant7_resp.dat
# infant7_resp.hea
# infant7_resp.resp
# infant8_ecg.atr
# infant8_ecg.dat
# infant8_ecg.hea
# infant8_ecg.qrsc
# infant8_resp.dat
# infant8_resp.hea
# infant8_resp.resp
# infant9_ecg.atr
# infant9_ecg.dat
# infant9_ecg.hea
# infant9_ecg.qrsc
# infant9_resp.dat
# infant9_resp.hea
# infant9_resp.resp
# RECORDS
# SHA256SUMS.txt

# %% [markdown]
# ### Manual file selection

# %% [markdown]
# var = file_index from 1 to 10
# freq

# %% [markdown]
# Select one file manually for inspection and loaded with help of the wfdb library:

# %%
file_index = 3
file_ecg = os.path.join(data_dir, f"infant{file_index:d}_ecg")
file_resp = os.path.join(data_dir, f"infant{file_index:d}_resp")
print("Loading ECG file : ", file_ecg)
print("Loading RESP file: ", file_resp)
record_ecg = wfdb.rdrecord(file_ecg)
record_resp = wfdb.rdrecord(file_resp)
# Out:
# Loading ECG file :  /Users/lyl69/Desktop/Sets/infant3_ecg
# Loading RESP file:  /Users/lyl69/Desktop/Sets/infant3_resp

# %% [markdown]
# The loaded files contain lots of metadata, the actual ECG/RESP waveforms are stored as arrays.
# The `wfdb` package stored metadata and data in its own format `wfdb.io.record.Record`, but can be retrieved as a Python dictionary (`dict`):

# %%
d_ecg = record_ecg.__dict__
d_resp = record_resp.__dict__
print(d_ecg)
# Out:
# {'record_name': 'infant3_ecg', 'n_sig': 1, 'fs': 500, 'counter_freq': None, 'base_counter': None, 'sig_len': 78684614, 'base_time': None, 'base_date': None, 'comments': [], 'sig_name': ['II'], 'p_signal': array([[ 0.09467079],
#        [ 0.09993028],
#        [ 0.09467079],
#        ...,
#        [-0.83976496],
#        [-0.91427437],
#        [-0.94407814]]), 'd_signal': None, 'e_p_signal': None, 'e_d_signal': None, 'file_name': ['infant3_ecg.dat'], 'fmt': ['16'], 'samps_per_frame': [1], 'skew': [None], 'byte_offset': [None], 'adc_gain': [1140.7954], 'baseline': [11394], 'units': ['mV'], 'adc_res': [0], 'adc_zero': [0], 'init_value': [11502], 'checksum': [22904], 'block_size': [0]}

# %% [markdown]
# Some useful parameters are stored under the following keys:

# %%
print("ECG record: ", d_ecg['record_name'])
print("number of signals: ", d_ecg['n_sig'])
print("sampling frequency: ", d_ecg['fs'], "Hz")
print("Number of samples: ", d_ecg['sig_len'])
print("Signal name: ", d_ecg['sig_name'])
# Out:
# ECG record:  infant3_ecg
# number of signals:  1
# sampling frequency:  500 Hz
# Number of samples:  78684614
# Signal name:  ['II']

# %%
print("RESP record: ", d_resp['record_name'])
print("number of signals: ", d_resp['n_sig'])
print("sampling frequency: ", d_resp['fs'], "Hz")
print("Number of samples: ", d_resp['sig_len'])
print("Signal name: ", d_resp['sig_name'])
# Out:
# RESP record:  infant3_resp
# number of signals:  1
# sampling frequency:  50 Hz
# Number of samples:  7868296
# Signal name:  ['RESP']

# %% [markdown]
# **NOTE**: not all the records use the same sampling frequency, you should therefore read the sampling frequency from the metadata.

# %% [markdown]
# Next, extract the ECG/RESP data arrays and convert them into 1-dimensional arrays using `ravel`:

# %%
x_ecg = d_ecg['p_signal'].ravel()
print("Number of ECG samples: ", x_ecg.shape[0], " data type: ", x_ecg.dtype)
# Out:
# Number of ECG samples:  78684614  data type:  float64

# %%
x_resp = d_resp['p_signal'].ravel()
print("Number of RESP samples: ", x_resp.shape[0], " data type: ", x_resp.dtype)
# Out:
# Number of RESP samples:  7868296  data type:  float64

# %% [markdown]
# Store the sampling rates as separate variables:

# %%
fs_ecg = d_ecg['fs'] # ECG sampling rate in Hz
dt_ecg = 1/fs_ecg # ECG sampling interval in sec.
fs_resp = d_resp['fs'] # RESP sampling rate in Hz
dt_resp = 1/fs_resp # RESP sampling interval in sec.
print("ECG sampling frequency: ", fs_ecg, " Hz")
print("ECG sampling interval dt = ", dt_ecg, " sec.")
print("RESP sampling frequency: ", fs_resp, " Hz")
print("RESP sampling interval dt = ", dt_resp, " sec.")
# Out:
# ECG sampling frequency:  500  Hz
# ECG sampling interval dt =  0.002  sec.
# RESP sampling frequency:  50  Hz
# RESP sampling interval dt =  0.02  sec.

# %% [markdown]
# ### Select time window manually

# %%
# set display time limits manually, recordings are many hours, millions of data points...
#t0_sec, t1_sec = 90620, 90640 # seconds

# ...or, if you want to look at the whole recording:
t0_sec, t1_sec = 0, x_resp.shape[0]*dt_resp # seconds, based on RESP signal

# convert seconds to samples, respect different sampling rates for ECG and RESP signals
t0_sample_ecg = round(t0_sec * fs_ecg)
t1_sample_ecg = round(t1_sec * fs_ecg)
t0_sample_resp = round(t0_sec * fs_resp)
t1_sample_resp = round(t1_sec * fs_resp)

# %% [markdown]
# Plot the result in an external window for inspection:

# %%
# this tells the notebook to open figures outside of the notebook
#%matplotlib qt
# %matplotlib inline

time_ecg = np.arange(x_ecg.shape[0])*dt_ecg # ECG time axis
time_resp = np.arange(x_resp.shape[0])*dt_resp # RESP time axis

fig1, ax = plt.subplots(2, 1, figsize=(16,4), sharex=True)
ax[0].plot(time_ecg[t0_sample_ecg:t1_sample_ecg], x_ecg[t0_sample_ecg:t1_sample_ecg], '-k', lw=0.5)
ax[1].plot(time_resp[t0_sample_resp:t1_sample_resp], x_resp[t0_sample_resp:t1_sample_resp], '-k', lw=0.5)
ax[0].set_xlabel("time [sec]")
ax[1].set_xlabel("time [sec]")
ax[0].set_title("ECG")
ax[1].set_title("RESP")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## PART 2: Selection of Sample Segments

# %% [markdown]
# Use the manually selected segment borders (in seconds) that were identified visually using `picsdb1_inspect.ipynb`:

# %%
#A
segments = {}
for i in range(10):
    key = f"infant{i+1:d}"
    segments[key] = []
#segments['infant1'] = [(3550, 3750), (4720,4822), (5100,5280), (7760,7870), (11435,11550)]
#segments['infant1'] = [(3550,7870)]
segments['infant2'] = [(3990,12080)]
segments['infant1'] = [(5110,11550)]
segments['infant3'] = [(5575,13940)]
segments['infant4'] = [(5860,12980)]
segments['infant5'] = [(103750,147350)] #FINAL
segments['infant6'] = [(7130,13670)]
segments['infant7'] = [(5060,13630)]
segments['infant8'] = [(4880,14570)]
segments['infant9'] = [(5940,12580)]
segments['infant10'] = [(3225,14710)]

# %% [markdown]
# ## PART 3: Selecting thresholds for peak detection for each sample
#
# Part 3 will be re-ran every segement. The final thresholds selected will be recorded in columns D to K of 'Preterm Infant Data Input Settings Blank' excel spreadsheet.
#
# Our complete and filled out excel spreadsheet is titled 'Preterm Infant Data Input Settings'. Refer to that if wanting to produce our exact results.

# %% [markdown]
# **Step One: Select segement to work with**
#
# Select a segment to work with by entering in an Infant number/ file_index (1 to 10) and a segement number

# %% [markdown]
# file_index = 2 # 1...10, loads data from infant1 ... infant10
# segment_index = 0

# %%
file_index = 9# 1...10, loads data from infant1 ... infant10
segment_index = 0 # 0,...

# %% [markdown]
# **Step Two: Import all the revelent data for that segement**
#
# Similar to part 1, the data will be imported but only part of the signal. Part 2, Step Two created a dictionary that will be used so the correct segment of time is selected from the overall signal and Part 3, Step One determines which segment it is.

# %% [markdown]
# ## Data import

# %%
x_ecg_full, x_resp_full, fs_ecg, fs_resp = load_waveforms(data_dir, file_index)
dt_ecg = 1/fs_ecg # ECG sampling interval in sec.
dt_resp = 1/fs_resp # RESP sampling interval in sec.
print("ECG sampling interval dt = ", dt_ecg, " sec.")
print("RESP sampling interval dt = ", dt_resp, " sec.")
# Out:
# Loading ECG file:  infant9_ecg
# Loading RESP file:  infant9_resp
# ECG sampling frequency:  500  Hz
# RESP sampling frequency:  50  Hz
# ECG sampling interval dt =  0.002  sec.
# RESP sampling interval dt =  0.02  sec.

# %% [markdown]
# Clip data to segment borders:

# %%
# get segment borders in seconds from the 'segments' dictionary
t0_sec, t1_sec = segments[f"infant{file_index:d}"][segment_index]
# convert seconds to samples, respect different sampling rates for ECG and RESP signals
t0_sample_ecg = round(t0_sec * fs_ecg)
t1_sample_ecg = round(t1_sec * fs_ecg)
t0_sample_resp = round(t0_sec * fs_resp)
t1_sample_resp = round(t1_sec * fs_resp)

# %% [markdown]
# Extract the ECG and RESP data arrays and convert them to a 1-dimensional arrays:

# %%
x_ecg = x_ecg_full[t0_sample_ecg:t1_sample_ecg] #sample for ecg
x_resp = x_resp_full[t0_sample_resp:t1_sample_resp]
print("number of ECG samples: ", len(x_ecg) , " data type: ", x_ecg.dtype)
print("number of RESP samples: ", x_resp.shape[0], " data type: ", x_resp.dtype)
# Out:
# number of ECG samples:  3320000  data type:  float64
# number of RESP samples:  332000  data type:  float64

# %%
del x_ecg_full, x_resp_full # free memory

# %% [markdown]
# Invert ECG signal if necessary.

# %% [markdown]
# mn = np.min(x_ecg-np.median(x_ecg))
# mx = np.max(x_ecg-np.median(x_ecg))
# if np.abs(mn) > np.abs(mx):
#     print("Invert ECG signal!")
#     x_ecg = -x_ecg

# %% [markdown]
# **Step Three: Plot the signal to check the segment selected**

# %% [markdown]
# **Step Four: Define a few functions to process the signal with**
#
# - A) Bandwidth filter (filters out extreme frequency signals that are out of what's is physically possible)
# - B) Local Maxima- to detect the peak of a wave
# - C) Histogram- to look at distribution
# - D) Interval Statistics
#
# **NOTE**: These functions have been moved from the notebook into the external file `picsdb.py`

# %% [markdown]
# # ECG/RESP peak detection algorithm

# %% [markdown]
# ## Plot power spectra
#
# First, inspect the power spectral densities of ECG/RESP signals to get an idea of useful settings for the band-pass filters.

# %% [markdown]
# **Resample the ecg sig**

# %%
freq_lo_ecg = 20
freq_hi_ecg = 125 # if is 1 or 5, use 120
freq_lo_resp = 0.5
freq_hi_resp = 5 # 5
x_ecg_filt  = bp_filter(x_ecg, fs_ecg, freq_lo_ecg, freq_hi_ecg)
x_ecg=x_ecg_filt
x_resp_filt = bp_filter(x_resp, fs_resp, freq_lo_resp, freq_hi_resp)
x_resp=x_resp_filt

# %%
if(fs_resp!=50):
    x_resp=processing.resample_sig(x_resp,fs=fs_resp,fs_target=50)
    fs_resp=50
    dt_resp=1/fs_resp

# %% [markdown]
# base on ecg and resp freq

# %%
len(x_ecg)
# Out:
# 3320000

# %%
len(x_resp)
# Out:
# 332000

# %%
x_resp_flow=[]
x_ecg_flow=[]
resp_counter=int(5/dt_resp)
ecg_counter=int(5/dt_ecg)
resp_index=int(5/dt_resp)
ecg_index=int(5/dt_ecg)
ecg_temp=[]
resp_temp=[]
count_resp=int(len(x_resp)/resp_counter)
count_ecg=int(len(x_ecg)/ecg_counter)
start=int(0)
for i in range(count_resp):
    temp=x_resp[start:resp_index]
    x_resp_flow.append(temp)
    start=resp_index
    resp_index=int(resp_index+resp_counter)
    temp=[]
start=int(0)
for j in range(count_ecg):
    temp=x_ecg[start:ecg_index]
    x_ecg_flow.append(temp)
    start=ecg_index
    ecg_index=int(ecg_index+ecg_counter)
    temp=[]

# %% [markdown]
# **Get the single resp wave**

# %%
print(len(x_resp)/resp_counter)
print(len(x_ecg)/ecg_counter)
print(len(x_resp_flow))
print(len(x_ecg_flow))
print(len(x_resp_flow[2]))
print(len(x_ecg_flow[15]))
# Out:
# 1328.0
# 1328.0
# 1328
# 1328
# 250
# 2500

# %%
time_line = np.arange(len(x_ecg_flow[0]))*dt_resp
fig2, ax = plt.subplots(5, 1, figsize=(16,15), sharex=True)
#x_resp_flow.remove(x_resp_flow[0])
#x_temp.remove(x_temp[0])
#x_ecg_flow.remove(x_ecg_flow[0])
j=0
for i in range(0,5):
    ax[j].plot(time_line, x_ecg_flow[i], '-k', lw=1)
    ax[j].set_xlabel("time [sec]")
    ax[j].set_title("RESP")
    j+=1

plt.tight_layout()
plt.show()

# %% [markdown]
# **conbain the uncontinue data**

# %% [markdown]
# **remove some data**
#
# I still working on finding someway to fix the discontinuous data, so I drop them.
#
# If we can combain the discontinuous data, this function can be delete

# %% [markdown]
# **find the R wave for each part ecg wave**

# %%
lomx=[]
w=1
for z in x_ecg_flow:
    c=locmax(z)
    ecg_peaks = np.array([np.mean(z[i-w:i+w]) for i in c])
    c = np.array([j for i, j in enumerate(c) if ecg_peaks[i] >1.0]) #ecg_peacks > 0.12 / 0.2
    lomx.append(c)
print(len(lomx))
# Out:
# 1328

# %%
lomx
# Out:
# [array([ 191,  413,  639,  864, 1096, 1328, 1559, 1790, 2019, 2247, 2475],
#        dtype=int64),
#  array([ 202,  427,  652,  877, 1099, 1321, 1542, 1762, 1982, 2200, 2417],
#        dtype=int64),
#  array([ 135,  352,  568,  785, 1004, 1223, 1443, 1662, 1879, 2098, 2316],
#        dtype=int64),
#  array([  34,  252,  469,  686,  903, 1119, 1335, 1551, 1767, 1983, 2198,
#         2415], dtype=int64),
#  array([ 131,  347,  563,  780, 1000, 1219, 1443, 1665, 1890, 2114, 2339],
#        dtype=int64),
#  array([  63,  287,  512,  737,  963, 1189, 1416, 1642, 1870, 2099, 2326],
#        dtype=int64),
#  array([  56,  286,  514,  740,  966, 1191, 1415, 1638, 1859, 2081, 2302],
#        dtype=int64),
#  array([  23,  243,  463,  683,  907, 1131, 1360, 1588, 1814, 2040, 2267,
#         2495], dtype=int64),
#  array([ 224,  453,  681,  909, 1136, 1364, 1591, 1818, 2044, 2269, 2495],
#        dtype=int64),
#  array([ 221,  446,  672,  897, 1121, 1345, 1570, 1794, 2018, 2241, 2465],
#        dtype=int64),
#  array([ 188,  409,  631,  853, 1074, 1296, 1517, 1739, 1962, 2185, 2408],
#        dtype=int64),
#  array([ 132,  356,  579,  803, 1026, 1249, 1472, 1697, 1922, 2147, 2372],
#        dtype=int64),
#  array([  98,  323,  548,  773,  997, 1221, 1444, 1667, 1890, 2113, 2336],
#        dtype=int64),
#  array([  59,  280,  503,  724,  945, 1166, 1386, 1607, 1827, 2047, 2268,
#         2487], dtype=int64),
#  array([ 208,  429,  651,  874, 1096, 1319, 1541, 1764, 1987, 2212, 2438],
#        dtype=int64),
#  array([ 164,  392,  621,  850, 1077, 1308, 1542, 1774, 2008, 2240, 2472],
#        dtype=int64),
#  array([ 203,  432,  661,  887, 1114, 1340, 1564, 1789, 2011, 2235, 2459],
#        dtype=int64),
#  array([ 187,  415,  643,  872, 1103, 1333, 1565, 1804, 2050, 2297],
#        dtype=int64),
#  array([  38,  277,  517,  755,  992, 1226, 1459, 1693, 1923, 2154, 2385],
#        dtype=int64),
#  array([ 115,  343,  572,  799, 1027, 1255, 1487, 1718, 1953, 2192, 2427],
#        dtype=int64),
#  array([ 163,  400,  635,  872, 1111, 1347, 1581, 1815, 2044, 2274],
#        dtype=int64),
#  array([   7,  236,  464,  692,  916, 1140, 1364, 1588, 1811, 2033, 2253,
#         2473], dtype=int64),
#  array([ 192,  411,  630,  847, 1065, 1281, 1498, 1713, 1929, 2144, 2359],
#        dtype=int64),
#  array([  73,  287,  501,  714,  927, 1140, 1353, 1565, 1778, 1991, 2203,
#         2418], dtype=int64),
#  array([ 132,  345,  559,  774,  988, 1205, 1421, 1637, 1857, 2078, 2305],
#        dtype=int64),
#  array([  29,  256,  482,  705,  929, 1154, 1379, 1602, 1824, 2046, 2268,
#         2491], dtype=int64),
#  array([ 216,  441,  670,  904, 1136, 1368, 1597, 1826, 2053, 2280],
#        dtype=int64),
#  array([   7,  235,  464,  691,  918, 1146, 1373, 1599, 1825, 2055, 2284],
#        dtype=int64),
#  array([  12,  238,  462,  687,  910, 1133, 1355, 1577, 1797, 2018, 2237,
#         2456], dtype=int64),
#  array([ 177,  403,  629,  854, 1079, 1307, 1540, 1770, 1999, 2228, 2456],
#        dtype=int64),
#  array([ 183,  409,  634,  858, 1080, 1302, 1522, 1743, 1960, 2177],
#        dtype=int64),
#  array([ 110,  324,  751,  963, 1175, 1805, 2079, 2223], dtype=int64),
#  array([ 138,  345,  963, 1374], dtype=int64),
#  array([  91,  999, 1101, 2296], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([1521], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([1268, 1697], dtype=int64),
#  array([], dtype=float64),
#  array([1618, 1829, 2038], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([ 349, 2258], dtype=int64),
#  array([ 839, 2372], dtype=int64),
#  array([2319], dtype=int64),
#  array([], dtype=float64),
#  array([1856], dtype=int64),
#  array([1609], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([977], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([1253, 2156], dtype=int64),
#  array([2305], dtype=int64),
#  array([2360], dtype=int64),
#  array([327], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([2000, 2216], dtype=int64),
#  array([], dtype=float64),
#  array([61], dtype=int64),
#  array([1309], dtype=int64),
#  array([ 806, 1895], dtype=int64),
#  array([], dtype=float64),
#  array([  59, 1825, 2049], dtype=int64),
#  array([ 450, 1137, 2054], dtype=int64),
#  array([229, 678], dtype=int64),
#  array([  18,  247,  925, 2049], dtype=int64),
#  array([434], dtype=int64),
#  array([ 332, 1454, 2375], dtype=int64),
#  array([ 109, 2018, 2483], dtype=int64),
#  array([ 671, 2012, 2232, 2451], dtype=int64),
#  array([ 386, 2321], dtype=int64),
#  array([35], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([2455], dtype=int64),
#  array([ 858, 2258], dtype=int64),
#  array([], dtype=float64),
#  array([ 391,  613,  838, 2180], dtype=int64),
#  array([350], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([359], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([153], dtype=int64),
#  array([], dtype=float64),
#  array([355], dtype=int64),
#  array([144, 829], dtype=int64),
#  array([412, 640], dtype=int64),
#  array([ 157,  815, 1033], dtype=int64),
#  array([ 486, 1140, 1360], dtype=int64),
#  array([632], dtype=int64),
#  array([], dtype=float64),
#  array([   5,  710, 2087], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([1258], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([157], dtype=int64),
#  array([], dtype=float64),
#  array([160], dtype=int64),
#  array([662], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([948], dtype=int64),
#  array([330], dtype=int64),
#  array([ 860, 1092], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([1430, 2357], dtype=int64),
#  array([1554], dtype=int64),
#  array([705, 940], dtype=int64),
#  array([2448], dtype=int64),
#  array([ 868, 1096], dtype=int64),
#  array([], dtype=float64),
#  array([ 288,  985, 1461, 1700], dtype=int64),
#  array([ 403, 1583], dtype=int64),
#  array([756], dtype=int64),
#  array([1229], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([1242], dtype=int64),
#  array([1607], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([ 806, 1052, 2031], dtype=int64),
#  array([ 736, 1205, 1443], dtype=int64),
#  array([1322], dtype=int64),
#  array([1109, 1572, 1803], dtype=int64),
#  array([702], dtype=int64),
#  array([ 812, 1045], dtype=int64),
#  array([ 892, 1127, 1359], dtype=int64),
#  array([ 235, 1812, 2476], dtype=int64),
#  array([], dtype=float64),
#  array([1953], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([ 896, 1114], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([2349], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([1765], dtype=int64),
#  array([ 445,  678,  910, 1141], dtype=int64),
#  array([1215, 1448, 1912, 2143], dtype=int64),
#  array([ 559,  790, 1485, 2179], dtype=int64),
#  array([1543], dtype=int64),
#  array([1608], dtype=int64),
#  array([ 736, 1210, 2167], dtype=int64),
#  array([1345, 2048], dtype=int64),
#  array([1157], dtype=int64),
#  array([], dtype=float64),
#  array([1123, 1366, 1609, 1847], dtype=int64),
#  array([], dtype=float64),
#  array([1828], dtype=int64),
#  array([   7, 2004], dtype=int64),
#  array([1042, 1921], dtype=int64),
#  array([  87, 1424, 1873, 2097], dtype=int64),
#  array([  47,  938, 1162, 1614], dtype=int64),
#  array([  23,  488,  723, 1667, 2141], dtype=int64),
#  array([1268, 1955], dtype=int64),
#  array([ 146,  841, 1074, 1538, 1772, 2233, 2464], dtype=int64),
#  array([ 195, 1417, 2229], dtype=int64),
#  array([  25,  894, 2217], dtype=int64),
#  array([ 468, 1936], dtype=int64),
#  array([ 171,  665, 1654, 2142], dtype=int64),
#  array([1549], dtype=int64),
#  array([], dtype=float64),
#  array([2202], dtype=int64),
#  array([], dtype=float64),
#  array([ 503, 1813, 2256], dtype=int64),
#  array([2062, 2294], dtype=int64),
#  array([2049], dtype=int64),
#  array([ 209, 1633, 2137, 2387], dtype=int64),
#  array([ 133,  853, 1324, 1557, 2247], dtype=int64),
#  array([ 426, 1315, 1980], dtype=int64),
#  array([1643], dtype=int64),
#  array([ 627,  837, 2091, 2297], dtype=int64),
#  array([   3, 1879], dtype=int64),
#  array([1161, 2031], dtype=int64),
#  array([ 177, 1254, 1688, 2338], dtype=int64),
#  array([1561], dtype=int64),
#  array([ 148,  367, 1673, 2103, 2317], dtype=int64),
#  array([ 30, 244], dtype=int64),
#  array([ 140,  574, 1868, 2083], dtype=int64),
#  array([  14, 1099, 2415], dtype=int64),
#  array([ 360, 1045, 1509], dtype=int64),
#  array([ 789, 1883], dtype=int64),
#  array([1584, 2252, 2473], dtype=int64),
#  array([ 414,  852, 1713, 2136], dtype=int64),
#  array([ 508, 1199, 1890, 2122], dtype=int64),
#  array([ 303, 1631, 2068], dtype=int64),
#  array([ 457,  679,  901, 1127, 2231], dtype=int64),
#  array([ 385,  821, 1040], dtype=int64),
#  array([  76, 1408, 1848], dtype=int64),
#  array([   1,  217,  861, 1502, 2147], dtype=int64),
#  array([ 769, 1917, 2145], dtype=int64),
#  array([ 103,  334,  818, 1299, 1784], dtype=int64),
#  array([ 277, 1010, 1486, 1722, 2186], dtype=int64),
#  array([ 142,  367,  590, 1469, 1912], dtype=int64),
#  array([ 333,  816, 1067, 1321, 1832, 2344], dtype=int64),
#  array([ 606, 1099, 2051], dtype=int64),
#  array([ 506, 1218, 1933, 2168], dtype=int64),
#  array([824], dtype=int64),
#  array([1215, 2413], dtype=int64),
#  array([ 155,  397, 1378], dtype=int64),
#  array([ 566, 1053], dtype=int64),
#  array([], dtype=float64),
#  array([314], dtype=int64),
#  array([], dtype=float64),
#  array([  19,  244, 1593], dtype=int64),
#  array([228, 456, 912], dtype=int64),
#  array([ 261, 1880], dtype=int64),
#  array([ 374, 1120, 2379], dtype=int64),
#  array([ 881, 2365], dtype=int64),
#  array([ 104, 1993, 2460], dtype=int64),
#  array([426, 889], dtype=int64),
#  array([ 205,  649, 1091, 2417], dtype=int64),
#  array([ 371, 1767, 1996], dtype=int64),
#  array([399, 622], dtype=int64),
#  array([ 139, 1062, 1788, 2294], dtype=int64),
#  array([ 557, 1056, 2479], dtype=int64),
#  array([ 437, 1116, 1792], dtype=int64),
#  array([ 416, 2198], dtype=int64),
#  array([ 595, 1065], dtype=int64),
#  array([ 794, 1030], dtype=int64),
#  array([1778], dtype=int64),
#  array([1082], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([ 318, 2294], dtype=int64),
#  array([  44, 1033, 2276], dtype=int64),
#  array([274], dtype=int64),
#  array([199, 939], dtype=int64),
#  array([606], dtype=int64),
#  array([], dtype=float64),
#  array([   4,  983, 1475], dtype=int64),
#  array([ 644, 1356], dtype=int64),
#  array([53], dtype=int64),
#  array([882], dtype=int64),
#  array([1347], dtype=int64),
#  array([425], dtype=int64),
#  array([], dtype=float64),
#  array([971], dtype=int64),
#  array([571], dtype=int64),
#  array([ 756, 1428], dtype=int64),
#  array([  72,  299,  975, 1867], dtype=int64),
#  array([ 248, 1129, 2050], dtype=int64),
#  array([1456], dtype=int64),
#  array([1262], dtype=int64),
#  array([], dtype=float64),
#  array([1129], dtype=int64),
#  array([ 182,  845, 1064], dtype=int64),
#  array([949], dtype=int64),
#  array([ 645, 1974], dtype=int64),
#  array([1018, 1239], dtype=int64),
#  array([ 494,  942, 1395, 1860], dtype=int64),
#  array([1209, 1674], dtype=int64),
#  array([1707], dtype=int64),
#  array([ 347,  577, 1035], dtype=int64),
#  array([ 373,  829, 1732], dtype=int64),
#  array([ 792, 1014], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([1225, 1447, 2389], dtype=int64),
#  array([ 638, 1129, 1613], dtype=int64),
#  array([ 772, 1244, 1935], dtype=int64),
#  array([ 773, 1427], dtype=int64),
#  array([1930], dtype=int64),
#  array([1024, 2395], dtype=int64),
#  array([ 588, 1060, 1766], dtype=int64),
#  array([670], dtype=int64),
#  array([ 905, 1583], dtype=int64),
#  array([], dtype=float64),
#  array([1345], dtype=int64),
#  array([  52,  579,  849, 1387, 1913, 2424], dtype=int64),
#  array([], dtype=float64),
#  array([1648, 1879], dtype=int64),
#  array([ 971, 1204], dtype=int64),
#  array([1257, 2010], dtype=int64),
#  array([ 461, 1161, 1908], dtype=int64),
#  array([ 419, 1907], dtype=int64),
#  array([845], dtype=int64),
#  array([933], dtype=int64),
#  array([  54, 1255, 1972], dtype=int64),
#  array([1830], dtype=int64),
#  array([1594], dtype=int64),
#  array([], dtype=float64),
#  array([1762], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([1821], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([1655], dtype=int64),
#  array([1732], dtype=int64),
#  array([ 153, 1321], dtype=int64),
#  array([], dtype=float64),
#  array([ 300, 1642], dtype=int64),
#  array([ 486, 1406, 2394], dtype=int64),
#  array([2148], dtype=int64),
#  array([ 126, 1548, 1785, 2255], dtype=int64),
#  array([1785, 2436], dtype=int64),
#  array([ 806, 1025], dtype=int64),
#  array([1246, 1716, 2192], dtype=int64),
#  array([859], dtype=int64),
#  array([1488, 1997], dtype=int64),
#  array([ 502, 2166], dtype=int64),
#  array([1795], dtype=int64),
#  array([14], dtype=int64),
#  array([1884], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([1802, 2029, 2259], dtype=int64),
#  array([225], dtype=int64),
#  array([], dtype=float64),
#  array([2313], dtype=int64),
#  array([2360], dtype=int64),
#  array([358], dtype=int64),
#  array([1285], dtype=int64),
#  array([2119], dtype=int64),
#  array([2199], dtype=int64),
#  array([], dtype=float64),
#  array([223], dtype=int64),
#  array([], dtype=float64),
#  array([2460], dtype=int64),
#  array([], dtype=float64),
#  array([2227], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([  99,  324,  790, 1525, 2302], dtype=int64),
#  array([322], dtype=int64),
#  array([], dtype=float64),
#  array([800], dtype=int64),
#  array([], dtype=float64),
#  array([2209, 2439], dtype=int64),
#  array([ 171, 1320, 2279], dtype=int64),
#  array([1314], dtype=int64),
#  array([845], dtype=int64),
#  array([1681], dtype=int64),
#  array([], dtype=float64),
#  array([165], dtype=int64),
#  array([], dtype=float64),
#  array([1237, 1903, 2126, 2351], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([2263], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([264], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([381], dtype=int64),
#  array([], dtype=float64),
#  array([ 113,  786, 2392], dtype=int64),
#  array([126], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([532], dtype=int64),
#  array([], dtype=float64),
#  array([619], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([ 467,  929, 1163, 1396], dtype=int64),
#  array([], dtype=float64),
#  array([ 697, 1377, 1829], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([1637], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([1027], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([320], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([2496], dtype=int64),
#  array([], dtype=float64),
#  array([110], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([ 364, 2109, 2331], dtype=int64),
#  array([  59,  740,  974, 1537, 2104, 2366], dtype=int64),
#  array([ 135, 1168, 1691, 1945, 2232, 2492], dtype=int64),
#  array([ 273,  531,  805, 1323, 1573, 1824, 2315], dtype=int64),
#  array([  71,  320,  564, 1044, 1969, 2420], dtype=int64),
#  array([ 145,  372, 1502, 1949, 2396], dtype=int64),
#  array([339], dtype=int64),
#  array([235, 451], dtype=int64),
#  array([ 116,  335, 1450], dtype=int64),
#  array([73], dtype=int64),
#  array([765], dtype=int64),
#  array([ 101, 1454, 2123], dtype=int64),
#  array([288], dtype=int64),
#  array([1094, 1766], dtype=int64),
#  array([ 621, 1301], dtype=int64),
#  array([379], dtype=int64),
#  array([  85,  745, 1190, 1863], dtype=int64),
#  array([ 492, 1163], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([1951], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([333], dtype=int64),
#  array([2136], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([1869], dtype=int64),
#  array([458], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([ 943, 1166, 1389], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([1760], dtype=int64),
#  array([1244], dtype=int64),
#  array([762], dtype=int64),
#  array([991], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([1964], dtype=int64),
#  array([1048, 1747], dtype=int64),
#  array([ 640, 1337], dtype=int64),
#  array([1092, 1311], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([1606], dtype=int64),
#  array([1306], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([2016, 2239, 2461], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([1874], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([588], dtype=int64),
#  array([1024, 1241, 1671], dtype=int64),
#  array([], dtype=float64),
#  array([2121], dtype=int64),
#  array([298], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([1096], dtype=int64),
#  array([1951], dtype=int64),
#  array([2169], dtype=int64),
#  array([1033, 1721], dtype=int64),
#  array([1946], dtype=int64),
#  array([], dtype=float64),
#  array([1355], dtype=int64),
#  array([], dtype=float64),
#  array([1679], dtype=int64),
#  array([1878], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([1540], dtype=int64),
#  array([2372], dtype=int64),
#  array([1632, 2289], dtype=int64),
#  array([], dtype=float64),
#  array([1267, 2392], dtype=int64),
#  array([ 781, 1226, 1885, 2323], dtype=int64),
#  array([], dtype=float64),
#  array([ 169, 1265, 1709], dtype=int64),
#  array([ 563, 1236, 2351], dtype=int64),
#  array([ 517, 1623], dtype=int64),
#  array([1516, 2386], dtype=int64),
#  array([2133], dtype=int64),
#  array([1444, 2364], dtype=int64),
#  array([  89,  313, 2085], dtype=int64),
#  array([262], dtype=int64),
#  array([], dtype=float64),
#  array([ 938, 1634, 2114], dtype=int64),
#  array([1257], dtype=int64),
#  array([ 538, 1409], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([315, 541], dtype=int64),
#  array([ 756, 1420], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([  70, 1905], dtype=int64),
#  array([82], dtype=int64),
#  array([ 213,  646, 1079, 1935, 2363], dtype=int64),
#  array([75], dtype=int64),
#  array([], dtype=float64),
#  array([1881], dtype=int64),
#  array([1626], dtype=int64),
#  array([2047], dtype=int64),
#  array([225], dtype=int64),
#  array([   9,  237,  465,  693, 1816, 2037], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([1072, 1512], dtype=int64),
#  array([101], dtype=int64),
#  array([], dtype=float64),
#  array([ 911, 2289], dtype=int64),
#  array([], dtype=float64),
#  array([965], dtype=int64),
#  array([ 543, 1944], dtype=int64),
#  array([142, 825], dtype=int64),
#  array([103, 990], dtype=int64),
#  array([ 15, 231, 446], dtype=int64),
#  array([ 298,  944, 2452], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([ 254,  942, 2080], dtype=int64),
#  array([2010], dtype=int64),
#  array([ 838, 2398], dtype=int64),
#  array([119], dtype=int64),
#  array([ 285,  965, 1899, 2368], dtype=int64),
#  array([ 335,  801, 1259, 2166, 2392], dtype=int64),
#  array([ 567,  792, 1469, 2370], dtype=int64),
#  array([ 549, 1451], dtype=int64),
#  array([ 319,  776, 1237, 1707, 1941], dtype=int64),
#  array([ 611, 1535, 1765, 2227], dtype=int64),
#  array([ 414, 1994], dtype=int64),
#  array([160, 381, 830], dtype=int64),
#  array([ 130,  578, 1486, 2170, 2400], dtype=int64),
#  array([ 128,  808, 1256, 1702, 1925, 2366], dtype=int64),
#  array([  86,  523,  959, 1394, 2263, 2480], dtype=int64),
#  array([ 638,  863, 1332, 2038], dtype=int64),
#  array([ 483, 1411], dtype=int64),
#  array([ 496, 1166, 2271, 2491], dtype=int64),
#  array([ 648,  866, 1520, 1959], dtype=int64),
#  array([ 325,  754, 2280], dtype=int64),
#  array([ 920, 1381, 2069], dtype=int64),
#  array([  27,  723,  956, 1187], dtype=int64),
#  array([ 509,  737, 1193, 1423, 1886, 2353], dtype=int64),
#  array([  86,  319,  556,  793, 1265], dtype=int64),
#  array([ 591, 1270, 1726, 1954], dtype=int64),
#  array([], dtype=float64),
#  array([ 961, 1820, 2252], dtype=int64),
#  array([ 184,  615,  836, 1271, 1492, 1933], dtype=int64),
#  array([ 100,  323, 1222, 1451, 1900, 2129], dtype=int64),
#  array([  79,  308,  534,  759,  991, 1219, 1445, 1904], dtype=int64),
#  array([  89,  317,  544,  773, 1009, 1240, 1943], dtype=int64),
#  array([ 628,  920, 1189, 1455, 1715], dtype=int64),
#  array([ 670,  904, 1368, 1825, 2053], dtype=int64),
#  array([   4,  231,  455,  896, 1116, 1557], dtype=int64),
#  array([ 410, 1112, 1342, 1571], dtype=int64),
#  array([ 406,  625,  843, 1061, 1278], dtype=int64),
#  array([ 287,  932, 1148, 1581, 1798], dtype=int64),
#  array([ 837, 1058, 1283], dtype=int64),
#  array([ 567, 1012, 1458, 1680], dtype=int64),
#  array([  70,  734, 1176, 1838], dtype=int64),
#  array([1080, 1951], dtype=int64),
#  array([ 998, 1221], dtype=int64),
#  array([ 47, 929], dtype=int64),
#  array([ 611,  833, 1053], dtype=int64),
dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([660], dtype=int64),
#  array([1675], dtype=int64),
#  array([588], dtype=int64),
#  array([], dtype=float64),
#  array([ 725, 1185], dtype=int64),
#  array([], dtype=float64),
#  array([572, 804], dtype=int64),
#  array([ 722, 1197, 1665, 1897], dtype=int64),
#  array([  88,  781, 1251, 1487, 1959], dtype=int64),
#  array([ 618,  847, 1303], dtype=int64),
#  array([1295, 2458], dtype=int64),
#  array([ 188, 1321, 2204], dtype=int64),
#  array([358, 798], dtype=int64),
#  array([ 595, 1063], dtype=int64),
#  array([1391, 2349], dtype=int64),
#  array([  87, 1027, 1260, 1724, 1955], dtype=int64),
#  array([149], dtype=int64),
#  array([   1,  475,  711, 1186], dtype=int64),
#  array([1223], dtype=int64),
#  array([ 743, 1185, 1406], dtype=int64),
#  array([1098], dtype=int64),
#  array([ 166, 1505], dtype=int64),
#  array([2294], dtype=int64),
#  array([647], dtype=int64),
#  array([675], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([1624], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([ 469, 1645], dtype=int64),
#  array([1962], dtype=int64),
#  array([1563], dtype=int64),
#  array([2289], dtype=int64),
#  array([727, 973], dtype=int64),
#  array([1443], dtype=int64),
#  array([1133], dtype=int64),
#  array([], dtype=float64),
#  array([1488], dtype=int64),
#  array([2381], dtype=int64),
#  array([1931], dtype=int64),
#  array([2164], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([2339], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([2487], dtype=int64),
#  array([425], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([ 721, 1818], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([ 411,  626, 1900], dtype=int64),
#  array([ 667,  878, 1090, 1301], dtype=int64),
#  array([2197], dtype=int64),
#  array([2285], dtype=int64),
#  array([], dtype=float64),
#  array([615], dtype=int64),
#  array([1435], dtype=int64),
#  array([1953], dtype=int64),
#  array([], dtype=float64),
#  array([2418], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([1785, 2005], dtype=int64),
#  array([375], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([1898], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([ 142, 2166], dtype=int64),
#  array([], dtype=float64),
#  array([16], dtype=int64),
#  array([ 188,  853, 1074], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([ 847, 1062], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([ 314, 2316], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([ 833, 2193], dtype=int64),
#  array([368], dtype=int64),
#  array([], dtype=float64),
#  array([1571, 2004], dtype=int64),
#  array([ 363, 1004], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([2129], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([1408], dtype=int64),
#  array([], dtype=float64),
#  array([2300], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([742], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([2145], dtype=int64),
#  array([], dtype=float64),
#  array([254], dtype=int64),
#  array([], dtype=float64),
#  array([1243], dtype=int64),
#  array([], dtype=float64),
#  array([1119], dtype=int64),
#  array([ 847, 2221], dtype=int64),
#  array([1289], dtype=int64),
#  array([ 615, 1307], dtype=int64),
#  array([616], dtype=int64),
#  array([2483], dtype=int64),
#  array([ 435, 1105, 2430], dtype=int64),
#  array([1026, 1676, 2110], dtype=int64),
#  array([ 898, 1113, 1330, 2190], dtype=int64),
#  array([ 774, 1212], dtype=int64),
#  array([238, 887], dtype=int64),
#  array([2039], dtype=int64),
#  array([2333], dtype=int64),
#  array([1149], dtype=int64),
#  array([ 47, 742], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([1230, 1891], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([1556], dtype=int64),
#  array([], dtype=float64),
#  array([1764], dtype=int64),
#  array([], dtype=float64),
#  array([], dtype=float64),
#  array([ 543, 1471, 2153], dtype=int64),
#  array([1003], dtype=int64),
#  array([ 897, 1543], dtype=int64),
#  ...]

# %% [markdown]
# **compute the rate for each ecg wave**

# %%
timespan=d_ecg #ms
rate=[]
for i in lomx:
    if not len(i)==0:
        span=dt_ecg*(max(i)-min(i))/(len(i)-1)
        rate.append(60/span)
    else:
        rate.append(0)
# Out:
# C:\Users\lyl69\AppData\Local\Temp\ipykernel_33484\4290182661.py:5: RuntimeWarning: invalid value encountered in double_scalars
#   span=dt_ecg*(max(i)-min(i))/(len(i)-1)

# %%
rate
# Out:
# [131.34851138353764,
#  135.44018058690747,
#  137.55158184319117,
#  138.59722805543888,
#  135.86956521739128,
#  132.5673884224481,
#  133.5707925200356,
#  133.49514563106797,
#  132.1003963011889,
#  133.6898395721925,
#  135.13513513513513,
#  133.92857142857142,
#  134.04825737265415,
#  135.91433278418452,
#  134.52914798206277,
#  129.98266897746967,
#  132.9787234042553,
#  127.96208530805688,
#  127.82275244993609,
#  129.75778546712803,
#  127.90146849834201,
#  133.8199513381995,
#  138.44023996308258,
#  140.72494669509595,
#  138.05798435342845,
#  134.03736799350122,
#  130.8139534883721,
#  131.75230566534913,
#  135.02454991816694,
#  131.63668275559456,
#  135.4062186559679,
#  99.38476100331282,
#  72.81553398058253,
#  40.816326530612244,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  nan,
#  0,
#  0,
#  0,
#  0,
#  0,
#  69.93006993006993,
#  0,
#  142.85714285714286,
#  0,
#  0,
#  15.71503404924044,
#  19.569471624266143,
#  nan,
#  0,
#  nan,
#  nan,
#  0,
#  0,
#  nan,
#  0,
#  0,
#  33.222591362126245,
#  nan,
#  nan,
#  nan,
#  0,
#  0,
#  0,
#  0,
#  138.88888888888889,
#  0,
#  nan,
#  nan,
#  27.548209366391184,
#  0,
#  30.150753768844222,
#  37.40648379052369,
#  66.81514476614699,
#  44.31314623338257,
#  nan,
#  29.36857562408223,
#  25.27379949452401,
#  50.561797752808985,
#  15.503875968992247,
#  nan,
#  0,
#  0,
#  nan,
#  21.428571428571427,
#  0,
#  50.30743432084963,
#  nan,
#  0,
#  0,
#  0,
#  0,
#  nan,
#  0,
#  0,
#  nan,
#  0,
#  nan,
#  43.7956204379562,
#  131.57894736842104,
#  68.4931506849315,
#  68.64988558352402,
#  nan,
#  0,
#  28.818443804034583,
#  0,
#  0,
#  0,
#  0,
#  nan,
#  0,
#  0,
#  0,
#  0,
#  nan,
#  0,
#  nan,
#  nan,
#  0,
#  0,
#  nan,
#  nan,
#  129.3103448275862,
#  0,
#  0,
#  32.362459546925564,
#  nan,
#  127.6595744680851,
#  nan,
#  131.57894736842104,
#  0,
#  63.73937677053825,
#  25.423728813559322,
#  nan,
#  nan,
#  0,
#  0,
#  0,
#  nan,
#  nan,
#  0,
#  0,
#  48.97959183673469,
#  84.86562942008487,
#  nan,
#  86.45533141210373,
#  nan,
#  128.75536480686694,
#  128.4796573875803,
#  26.77376171352075,
#  0,
#  nan,
#  0,
#  0,
#  0,
#  0,
#  137.61467889908258,
#  0,
#  0,
#  0,
#  0,
#  0,
#  nan,
#  0,
#  0,
#  nan,
#  129.3103448275862,
#  96.98275862068965,
#  55.55555555555555,
#  nan,
#  nan,
#  41.92872117400419,
#  42.674253200568984,
#  nan,
#  0,
#  124.30939226519338,
#  0,
#  nan,
#  15.022533800701051,
#  34.129692832764505,
#  44.776119402985074,
#  57.434588385449906,
#  56.657223796033996,
#  43.66812227074235,
#  77.65314926660913,
#  29.498525073746308,
#  27.372262773722625,
#  20.435967302452315,
#  45.662100456621005,
#  nan,
#  0,
#  nan,
#  0,
#  34.227039361095265,
#  129.3103448275862,
#  nan,

#  0,
#  0,
#  0,
#  nan,
#  0,
#  0,
#  0,
#  nan,
#  0,
#  nan,
#  0,
#  0,
#  nan,
#  0,
#  0,
#  0,
#  nan,
#  0,
#  nan,
#  0,
#  nan,
#  0,
#  nan,
#  21.834061135371176,
#  nan,
#  43.35260115606936,
#  nan,
#  nan,
#  30.075187969924812,
#  55.35055350553505,
#  69.6594427244582,
#  68.4931506849315,
#  46.22496147919877,
#  nan,
#  nan,
#  nan,
#  43.165467625899275,
#  0,
#  0,
#  45.3857791225416,
#  0,
#  0,
#  0,
#  nan,
#  0,
#  nan,
#  0,
#  0,
#  37.267080745341616,
#  nan,
#  46.43962848297213,
#  ...]

# %%
arr = np.nan_to_num(rate)
nanlist=[]

for i in range(len(arr)):
    if arr[i]<50 or arr[i]>190:
        nanlist.append(i)
finalrate=[]
if(not len(nanlist)==0):
    j=0
    for i in range(len(arr)):
        if j==len(nanlist):
            break
        if i==nanlist[j]:
            j+=1
            pass
        else:
            finalrate.append(arr[i])
        
    finalresp=[]
    y=0
    for z in range(len(x_resp_flow)):
        if y==len(nanlist):
            break
        if z==nanlist[y]:
            y+=1
            pass
        else:
            finalresp.append(x_resp_flow[z])
else:
    finalrate=arr
    finalresp=x_resp_flow

# %%
len(finalresp)
# Out:
# 318

# %% [markdown]
# **next step: remove incomplete ecg data for resp and ecg wave**
#
# finalrate
#
# finalresp

# %%
import csv

#python2可以用file替代open
with open("test_09.csv","w", newline="") as csvfile: 
    writer = csv.writer(csvfile)
    writer.writerows(finalresp)

# %%
for i in finalrate:
    print(i)
# Out:
# 131.34851138353764
# 135.44018058690747
# 137.55158184319117
# 138.59722805543888
# 135.86956521739128
# 132.5673884224481
# 133.5707925200356
# 133.49514563106797
# 132.1003963011889
# 133.6898395721925
# 135.13513513513513
# 133.92857142857142
# 134.04825737265415
# 135.91433278418452
# 134.52914798206277
# 129.98266897746967
# 132.9787234042553
# 127.96208530805688
# 127.82275244993609
# 129.75778546712803
# 127.90146849834201
# 133.8199513381995
# 138.44023996308258
# 140.72494669509595
# 138.05798435342845
# 134.03736799350122
# 130.8139534883721
# 131.75230566534913
# 135.02454991816694
# 131.63668275559456
# 135.4062186559679
# 99.38476100331282
# 72.81553398058253
# 69.93006993006993
# 142.85714285714286
# 138.88888888888889
# 66.81514476614699
# 50.561797752808985
# 50.30743432084963
# 131.57894736842104
# 68.4931506849315
# 68.64988558352402
# 129.3103448275862
# 127.6595744680851
# 131.57894736842104
# 63.73937677053825
# 84.86562942008487
# 86.45533141210373
# 128.75536480686694
# 128.4796573875803
# 137.61467889908258
# 129.3103448275862
# 96.98275862068965
# 55.55555555555555
# 124.30939226519338
# 57.434588385449906
# 56.657223796033996
# 77.65314926660913
# 129.3103448275862
# 56.764427625354784
# 53.89221556886228
# 55.325034578146614
# 140.18691588785046
# 52.21932114882507
# 67.49156355455568
# 52.264808362369344
# 55.762081784386616
# 67.64374295377678
# 91.6030534351145
# 55.91798695246971
# 71.38607971445568
# 62.86013619696176
# 67.79661016949153
# 74.58975634012928
# 54.15162454873646
# 90.49773755656108
# 121.95121951219512
# 141.9558359621451
# 136.36363636363637
# 67.72009029345372
# 139.53488372093022
# 69.28406466512702
# 55.35055350553505
# 69.6594427244582
# 68.4931506849315
# 135.13513513513513
# 140.18691588785046
# 61.47540983606557
# 72.70964614638875
# 79.22535211267605
# 68.3371298405467
# 54.005400540054005
# 70.75471698113208
# 141.50943396226415
# 50.139275766016716
# 50.718512256973796
# 67.56756756756756
# 90.56603773584906
# 54.84460694698354
# 56.232427366447986
# 129.87012987012986
# 82.41758241758242
# 104.65116279069767
# 50.933786078098464
# 133.92857142857142
# 51.1654349061967
# 57.27923627684964
# 58.62237420615534
# 79.4351279788173
# 50.526315789473685
# 66.66666666666667
# 57.47126436781609
# 51.66475315729047
# 59.7609561752988
# 91.6030534351145
# 65.14657980456026
# 78.294910830796
# 59.671805072103425
# 89.55223880597015
# 54.67800729040096
# 63.73937677053825
# 125.52301255230124
# 59.464816650148656
# 56.782334384858046
# 73.26007326007326
# 56.85407454200885
# 72.63922518159805
# 53.380782918149464
# 60.57546693589096
# 55.4016620498615
# 83.79888268156425
# 50.81874647092038
# 85.71428571428571
# 94.33962264150944
# 54.10279531109107
# 66.66666666666667
# 69.93006993006993
# 113.63636363636363
# 86.33093525179855
# 109.32944606413993
# 76.46559048428206
# 97.79951100244499
# 66.2251655629139
# 53.66726296958855
# 135.74660633484163
# 68.4931506849315
# 77.72020725388602
# 52.08333333333333
# 60.75949367088607
# 59.79073243647235
# 131.57894736842104
# 138.88888888888889
# 94.48818897637796
# 97.0873786407767
# 54.5950864422202
# 140.18691588785046
# 69.68641114982579
# 123.62637362637362
# 72.63922518159805
# 140.8450704225352
# 69.28406466512702
# 145.63106796116503
# 67.26457399103138
# 69.68641114982579
# 60.0

# %%
print(esganoijkc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[258], line 1
# ----> 1 print(esganoijkc)
#
# NameError: name 'esganoijkc' is not defined

# %%
import numpy as np
import pandas as pd
import glob
import re
csv_list = glob.glob('*.csv')
print('发现%s个CSV文件'% len(csv_list))
print('对文件进行处理中')
for i in csv_list:
    fr = open(i,'r',encoding='utf-8').read()
    with open('合并之后.csv','a',encoding='utf-8') as f:
        f.write(fr)
print('所有文件合并完成！')
# Out:
# 发现7个CSV文件
# 对文件进行处理中
# 所有文件合并完成！

# %% [markdown]
# freq_lo_ecg = 20
# freq_hi_ecg = 125 # if is 1 or 5, use 120
# freq_lo_resp = 0.5
# freq_hi_resp = 5 # 5
# time_ecg = np.arange(x_ecg.shape[0])*dt_ecg*1000
# time_resp = np.arange(x_resp.shape[0])*dt_resp
# plt.figure(figsize=(16,5))
# plt.scatter(time_ecg, x_ecg, color = 'hotpink',s=2)
# #plt.scatter(time_resp, x_resp, color = '#88c999')
# x_ecg_filter=bp_filter(x_ecg, fs_ecg, freq_lo_ecg, freq_hi_ecg)
# plt.xlabel("TIME STAMP")
# plt.ylabel("Signal")
# plt.scatter(time_ecg, x_ecg_filter, color = 'green',s=2)
# plt.title("Fliter function")
# plt.show()
